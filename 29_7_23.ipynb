# %% [markdown]
# <a href="https://colab.research.google.com/github/KarrasYiannis/Trading/blob/main/29_7_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-decouple binance
# !pip install python-binance
# !pip install pandas_ta
# Out:
# Collecting python-decouple
#   Downloading python_decouple-3.8-py3-none-any.whl (9.9 kB)
# Collecting binance
#   Downloading binance-0.3-py2.py3-none-any.whl (3.8 kB)
# Installing collected packages: python-decouple, binance
# Successfully installed binance-0.3 python-decouple-3.8
# Collecting python-binance
#   Downloading python_binance-1.0.17-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from python-binance) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from python-binance) (1.16.0)
# Collecting dateparser (from python-binance)
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from python-binance) (3.8.5)
# Collecting ujson (from python-binance)
#   Downloading ujson-5.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 6.6 MB/s eta 0:00:00
# Collecting websockets (from python-binance)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.0 MB/s eta 0:00:00
# Collecting pycryptodome (from python-binance)
#   Downloading pycryptodome-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 57.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->python-binance) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->python-binance) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->python-binance) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->python-binance) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->python-binance) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->python-binance) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->python-binance) (1.3.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser->python-binance) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser->python-binance) (2022.7.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser->python-binance) (2022.10.31)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->python-binance) (5.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->python-binance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->python-binance) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->python-binance) (3.4)
# Installing collected packages: websockets, ujson, pycryptodome, dateparser, python-binance
# Successfully installed dateparser-1.1.8 pycryptodome-3.18.0 python-binance-1.0.17 ujson-5.8.0 websockets-11.0.3
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218907 sha256=d074ee8dc5b55fca2da7ffc601532301f1b622d07382afeccaa409fc11ba9eb5
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0

# %%
API_Key= "yCDuE6E4PNgHGYG38rSU6NrwloW8akmCI86Hm7BDQHwqRNryWB1Li4QfDrrf1hyT"
Secret_Key="NUldRp4nkJFjBaOKVRQbQVpsADaxWeXnPpz08WCtO9B9Vd7wwYcJtogDOB1IJyZ6"

# %%
from decouple import config
from binance.client import Client
import pandas as pd
import pandas_ta as ta
import os
import json
import time
import sys
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-208abb8ea425> in <cell line: 1>()
# ----> 1 from decouple import config
#       2 from binance.client import Client
#       3 import pandas as pd
#       4 import pandas_ta as ta
#       5 import os
#
# ModuleNotFoundError: No module named 'decouple'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
client = Client(API_Key, Secret_Key, testnet = True)

# %%
balance = client.get_asset_balance(asset ='BTC')
# Out:
# {'asset': 'BTC', 'free': '1.00000000', 'locked': '0.00000000'}

# %%
def fetch_klines(asset):

    klines = client.get_historical_klines(asset, Client.KLINE_INTERVAL_1MINUTE, "1 hour ago UTC")
    print(klines)

    klines = [ [x[0],float(x[4])] for x in klines]

    klines =pd.DataFrame(klines, columns = ["time", "price"])
    klines['time'] =  pd.to_datetime(klines["time"], unit = "ms")

    return klines

# %%
def get_rsi(asset):

    klines = fetch_klines(asset)
    klines["rsi"] = ta.rsi( close = klines["price"], length = 14)

    print(klines)
    return klines["rsi"][-1]
get_rsi("BTCUSDT")
# Out:
# [[1690569780000, '29321.70000000', '29326.56000000', '29319.99000000', '29326.56000000', '4.54543500', 1690569839999, '133286.37842942', 86, '3.53277800', '103594.53615642', '0'], [1690569840000, '29324.00000000', '29334.58000000', '29321.89000000', '29334.58000000', '5.77139600', 1690569899999, '169267.13860811', 106, '3.30982900', '97073.86270864', '0'], [1690569900000, '29332.10000000', '29332.11000000', '29316.68000000', '29316.68000000', '2.53145900', 1690569959999, '74237.86036547', 77, '0.09432900', '2765.81997423', '0'], [1690569960000, '29316.67000000', '29316.68000000', '29314.22000000', '29315.00000000', '0.85793500', 1690570019999, '25150.62383565', 34, '0.21718000', '6366.70996134', '0'], [1690570020000, '29315.01000000', '29319.52000000', '29315.01000000', '29319.51000000', '1.44732900', 1690570079999, '42431.47844994', 45, '1.37885000',